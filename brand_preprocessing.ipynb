# %%
import pandas as pd

# %%
df = pd.read_csv('brand.csv')

# %%
df
# Out:
#        Unnamed: 0                               name          brand  \
# 0               0                      元山熱水瓶YS-540AP             元山
# 1               1                356612@姍拉娜治痘洗面乳150G            姍拉娜
# 2               2                    台鹽海洋鹼性離子水 600ML             台鹽
# 3               3                       妮傲絲翠果酸深層保養乳液    NEO-TEC妮傲絲翠
# 4               4            舒潔棉柔舒適迪士尼抽取式衛生紙 100抽16入             舒潔
# ...           ...                                ...            ...
# 70041       70041  惠而浦16公斤瓦斯型滾筒蒸氣(可堆疊)乾衣機8TWGD6622HW  惠而浦 Whirlpool
# 70042       70042                          康乃馨成人紙尿褲L            康乃馨
# 70043       70043               日本芮芙茹零矽靈洗髮露460ml頭皮保養     芮芙茹 Reveur
# 70044       70044                Crest長效鎖白牙膏-輕柔鑽白99g          crest
# 70045       70045             714171@雀巢咖啡三合一義式拿鐵16G*             雀巢
#
#                lower            Q2B        accents
# 0                 元山             元山             元山
# ...
